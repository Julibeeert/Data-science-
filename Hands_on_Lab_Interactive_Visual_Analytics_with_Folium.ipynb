# %% [markdown]
# <a href="https://colab.research.google.com/github/Julibeeert/Data-science-/blob/main/Hands_on_Lab_Interactive_Visual_Analytics_with_Folium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Laboratorio práctico: Análisis visual interactivo con Folium

# %%
# Instalar folium y pandas si no están ya instalados
# !pip install folium pandas

# Luego importar las librerías
import folium
import pandas as pd
import numpy as np
from folium.plugins import MarkerCluster

print("Todo listo para trabajar en el mapa 🌍")
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.4.26)
# Todo listo para trabajar en el mapa 🌍

# %%
import folium
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# ### **TAREA 1: Marcar todos los sitios de lanzamiento en un mapa**

# %%
# Solo para Google Colab
# !pip install folium pandas
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2025.4.26)

# %%
import folium
import pandas as pd
import numpy as np

# %%
# Datos de ejemplo (puedes reemplazarlos con tus propios datos)
launch_sites = pd.DataFrame({
    'Launch Site': ['CCAFS LC-40', 'VAFB SLC-4E', 'KSC LC-39A', 'CCAFS SLC-40'],
    'Lat': [28.562302, 34.632834, 28.573255, 28.563197],
    'Long': [-80.577356, -120.610746, -80.646895, -80.576820]
})

launch_sites
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1   VAFB SLC-4E  34.632834 -120.610746
# 2    KSC LC-39A  28.573255  -80.646895
# 3  CCAFS SLC-40  28.563197  -80.576820

# %%
# Crear el mapa centrado en EE.UU.
site_map = folium.Map(location=[30, -100], zoom_start=4)

# Agregar un marcador por cada sitio de lanzamiento
for index, row in launch_sites.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Long']],
        popup=row['Launch Site'],
        icon=folium.Icon(color='blue', icon='rocket', prefix='fa')
    ).add_to(site_map)

# Mostrar el mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_940b3150e992c577115234efd8721c13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_940b3150e992c577115234efd8721c13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_940b3150e992c577115234efd8721c13 = L.map(
#                 &quot;map_940b3150e992c577115234efd8721c13&quot;,
#                 {
#                     center: [30.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5c4aff780005c340bde593d5db5df30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5c4aff780005c340bde593d5db5df30.addTo(map_940b3150e992c577115234efd8721c13);
#
#
#             var marker_4d272ca4ddad43c78cabc71e5a294485 = L.marker(
#                 [28.562302, -80.577356],
#                 {
# }
#             ).addTo(map_940b3150e992c577115234efd8721c13);
#
#
#             var icon_b840dc68332c9e82802e795b93bc08f5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0e513d761a83b48da98feb6db8f413c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_120acd2de40963072bda9b182094e633 = $(`&lt;div id=&quot;html_120acd2de40963072bda9b182094e633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_0e513d761a83b48da98feb6db8f413c6.setContent(html_120acd2de40963072bda9b182094e633);
#
#
#
#         marker_4d272ca4ddad43c78cabc71e5a294485.bindPopup(popup_0e513d761a83b48da98feb6db8f413c6)
#         ;
#
#
#
#
#                 marker_4d272ca4ddad43c78cabc71e5a294485.setIcon(icon_b840dc68332c9e82802e795b93bc08f5);
#
#
#             var marker_eef351b2fa80b6d8455d347a454322c2 = L.marker(
#                 [34.632834, -120.610746],
#                 {
# }
#             ).addTo(map_940b3150e992c577115234efd8721c13);
#
#
#             var icon_1dd5ba9d63efbd6b464add6aa25a45ea = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_313d9a8ff08b5479f0178be9aa63ec2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_783230a3455bf3c132892f35107402d7 = $(`&lt;div id=&quot;html_783230a3455bf3c132892f35107402d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_313d9a8ff08b5479f0178be9aa63ec2f.setContent(html_783230a3455bf3c132892f35107402d7);
#
#
#
#         marker_eef351b2fa80b6d8455d347a454322c2.bindPopup(popup_313d9a8ff08b5479f0178be9aa63ec2f)
#         ;
#
#
#
#
#                 marker_eef351b2fa80b6d8455d347a454322c2.setIcon(icon_1dd5ba9d63efbd6b464add6aa25a45ea);
#
#
#             var marker_603110450eafc37b15e3c39dd779f379 = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(map_940b3150e992c577115234efd8721c13);
#
#
#             var icon_396b267100d3bee1eb1cc57f3b911d11 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d3781ab6fc3f7d703774bade621f0a41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c075c4dc935fd2bf67fc45c4a71bacb = $(`&lt;div id=&quot;html_6c075c4dc935fd2bf67fc45c4a71bacb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_d3781ab6fc3f7d703774bade621f0a41.setContent(html_6c075c4dc935fd2bf67fc45c4a71bacb);
#
#
#
#         marker_603110450eafc37b15e3c39dd779f379.bindPopup(popup_d3781ab6fc3f7d703774bade621f0a41)
#         ;
#
#
#
#
#                 marker_603110450eafc37b15e3c39dd779f379.setIcon(icon_396b267100d3bee1eb1cc57f3b911d11);
#
#
#             var marker_b25322c48c27ed1b579db9e101c11454 = L.marker(
#                 [28.563197, -80.57682],
#                 {
# }
#             ).addTo(map_940b3150e992c577115234efd8721c13);
#
#
#             var icon_0c7a0aceff574fc8cb94ea8b4566727a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quo

# %%
# Mostrar el mapa directamente en Jupyter Notebook
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_940b3150e992c577115234efd8721c13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_940b3150e992c577115234efd8721c13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_940b3150e992c577115234efd8721c13 = L.map(
#                 &quot;map_940b3150e992c577115234efd8721c13&quot;,
#                 {
#                     center: [30.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5c4aff780005c340bde593d5db5df30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5c4aff780005c340bde593d5db5df30.addTo(map_940b3150e992c577115234efd8721c13);
#
#
#             var marker_4d272ca4ddad43c78cabc71e5a294485 = L.marker(
#                 [28.562302, -80.577356],
#                 {
# }
#             ).addTo(map_940b3150e992c577115234efd8721c13);
#
#
#             var icon_b840dc68332c9e82802e795b93bc08f5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0e513d761a83b48da98feb6db8f413c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_120acd2de40963072bda9b182094e633 = $(`&lt;div id=&quot;html_120acd2de40963072bda9b182094e633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_0e513d761a83b48da98feb6db8f413c6.setContent(html_120acd2de40963072bda9b182094e633);
#
#
#
#         marker_4d272ca4ddad43c78cabc71e5a294485.bindPopup(popup_0e513d761a83b48da98feb6db8f413c6)
#         ;
#
#
#
#
#                 marker_4d272ca4ddad43c78cabc71e5a294485.setIcon(icon_b840dc68332c9e82802e795b93bc08f5);
#
#
#             var marker_eef351b2fa80b6d8455d347a454322c2 = L.marker(
#                 [34.632834, -120.610746],
#                 {
# }
#             ).addTo(map_940b3150e992c577115234efd8721c13);
#
#
#             var icon_1dd5ba9d63efbd6b464add6aa25a45ea = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_313d9a8ff08b5479f0178be9aa63ec2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_783230a3455bf3c132892f35107402d7 = $(`&lt;div id=&quot;html_783230a3455bf3c132892f35107402d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VAFB SLC-4E&lt;/div&gt;`)[0];
#                 popup_313d9a8ff08b5479f0178be9aa63ec2f.setContent(html_783230a3455bf3c132892f35107402d7);
#
#
#
#         marker_eef351b2fa80b6d8455d347a454322c2.bindPopup(popup_313d9a8ff08b5479f0178be9aa63ec2f)
#         ;
#
#
#
#
#                 marker_eef351b2fa80b6d8455d347a454322c2.setIcon(icon_1dd5ba9d63efbd6b464add6aa25a45ea);
#
#
#             var marker_603110450eafc37b15e3c39dd779f379 = L.marker(
#                 [28.573255, -80.646895],
#                 {
# }
#             ).addTo(map_940b3150e992c577115234efd8721c13);
#
#
#             var icon_396b267100d3bee1eb1cc57f3b911d11 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;rocket&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_d3781ab6fc3f7d703774bade621f0a41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c075c4dc935fd2bf67fc45c4a71bacb = $(`&lt;div id=&quot;html_6c075c4dc935fd2bf67fc45c4a71bacb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KSC LC-39A&lt;/div&gt;`)[0];
#                 popup_d3781ab6fc3f7d703774bade621f0a41.setContent(html_6c075c4dc935fd2bf67fc45c4a71bacb);
#
#
#
#         marker_603110450eafc37b15e3c39dd779f379.bindPopup(popup_d3781ab6fc3f7d703774bade621f0a41)
#         ;
#
#
#
#
#                 marker_603110450eafc37b15e3c39dd779f379.setIcon(icon_396b267100d3bee1eb1cc57f3b911d11);
#
#
#             var marker_b25322c48c27ed1b579db9e101c11454 = L.marker(
#                 [28.563197, -80.57682],
#                 {
# }
#             ).addTo(map_940b3150e992c577115234efd8721c13);
#
#
#             var icon_0c7a0aceff574fc8cb94ea8b4566727a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quo

# %% [markdown]
# Primero, intentemos agregar la ubicación de cada sitio en un mapa usando las coordenadas de latitud y longitud del sitio.
#
# El siguiente conjunto de datos, llamado spacex_launch_geo.csv, es un conjunto de datos ampliado que incluye la latitud y longitud agregadas para cada sitio.

# %%
# Importar pandas
import pandas as pd

# URL del dataset
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'

# Leer el CSV directamente desde la URL
spacex_df = pd.read_csv(url)

# Mostrar las primeras filas del DataFrame
spacex_df.head()
# Out:
#    Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0              1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1              2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2              3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3              4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4              5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#                                              Payload  Payload Mass (kg)  \
# 0               Dragon Spacecraft Qualification Unit                0.0
# 1  Dragon demo flight C1, two CubeSats,  barrel o...                0.0
# 2                             Dragon demo flight C2+              525.0
# 3                                       SpaceX CRS-1              500.0
# 4                                       SpaceX CRS-2              677.0
#
#        Orbit         Customer        Landing Outcome  class        Lat  \
# 0        LEO           SpaceX  Failure   (parachute)      0  28.562302
# 1  LEO (ISS)  NASA (COTS) NRO  Failure   (parachute)      0  28.562302
# 2  LEO (ISS)      NASA (COTS)             No attempt      0  28.562302
# 3  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
# 4  LEO (ISS)       NASA (CRS)             No attempt      0  28.562302
#
#         Long
# 0 -80.577356
# 1 -80.577356
# 2 -80.577356
# 3 -80.577356
# 4 -80.577356

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %% [markdown]
# Podemos usar folium.Circle para agregar un área circular resaltada con una etiqueta de texto en una coordenada específica. Por ejemplo:

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c7a98c0f28601effe55e2f39667cf36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c7a98c0f28601effe55e2f39667cf36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c7a98c0f28601effe55e2f39667cf36 = L.map(
#                 &quot;map_5c7a98c0f28601effe55e2f39667cf36&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35e42e788d15a729bb6403a90d306f62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_35e42e788d15a729bb6403a90d306f62.addTo(map_5c7a98c0f28601effe55e2f39667cf36);
#
#
#             var circle_c2d213fd5da2b3d736b749386e65c249 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5c7a98c0f28601effe55e2f39667cf36);
#
#
#         var popup_7208da9e53519d82918cb3b8d4975455 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91a01ef4b8dd2abfa74fa8aa80b497ce = $(`&lt;div id=&quot;html_91a01ef4b8dd2abfa74fa8aa80b497ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_7208da9e53519d82918cb3b8d4975455.setContent(html_91a01ef4b8dd2abfa74fa8aa80b497ce);
#
#
#
#         circle_c2d213fd5da2b3d736b749386e65c249.bindPopup(popup_7208da9e53519d82918cb3b8d4975455)
#         ;
#
#
#
#
#             var marker_835e0914382f271d6d406da8de9d44ae = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_5c7a98c0f28601effe55e2f39667cf36);
#
#
#             var div_icon_c9c8f98788c60daf8485be3bc223d0a3 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_835e0914382f271d6d406da8de9d44ae.setIcon(div_icon_c9c8f98788c60daf8485be3bc223d0a3);
#
#
#                 marker_835e0914382f271d6d406da8de9d44ae.setIcon(div_icon_c9c8f98788c60daf8485be3bc223d0a3);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Y deberías encontrar un pequeño círculo amarillo cerca de la ciudad de Houston. Puedes hacer zoom para ver un círculo más grande.
#
# Ahora, agreguemos un círculo para cada sitio de lanzamiento en el DataFrame launch_sites.
#
# POR HACER (TODO): Crear y agregar folium.Circle y folium.Marker para cada sitio de lanzamiento en el mapa (site_map).
#
# Un ejemplo de uso de folium.Circle:

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# Add the initial NASA JSC circle and marker as in the original code
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)

# Assuming launch_sites_df is already loaded from a previous cell
# Iterate through each launch site in the DataFrame
for index, site_info in launch_sites_df.iterrows():
    # Get the coordinates and launch site name
    site_coordinate = [site_info['Lat'], site_info['Long']]
    site_name = site_info['Launch Site']

    # Create a Circle for the launch site
    # You can customize radius, color, and fill based on requirements
    site_circle = folium.Circle(
        site_coordinate,
        radius=1000, # Example radius, adjust as needed
        color='#000000', # Example color
        fill=True,
        fill_color='#000000' # Example fill color
    ).add_child(folium.Popup(site_name)) # Add popup with site name

    # Create a Marker for the launch site with a text label
    site_marker = folium.map.Marker(
        site_coordinate,
        # Create an icon as a text label
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % site_name,
            )
        )

    # Add the circle and marker to the map
    site_map.add_child(site_circle)
    site_map.add_child(site_marker)

# Display the map (this would typically be the last line in a cell in a notebook)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5013d67b16cf6e16d6dca18bf9f80d14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5013d67b16cf6e16d6dca18bf9f80d14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5013d67b16cf6e16d6dca18bf9f80d14 = L.map(
#                 &quot;map_5013d67b16cf6e16d6dca18bf9f80d14&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f1c9693e31e556da710607ced4938cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f1c9693e31e556da710607ced4938cf.addTo(map_5013d67b16cf6e16d6dca18bf9f80d14);
#
#
#             var circle_4c98119315d5006866bcec59b0bad3cb = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5013d67b16cf6e16d6dca18bf9f80d14);
#
#
#         var popup_c0b0c39ce2d29e1b11c03b2ea8624e13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_770f865297c216e073c16c0dda9b448b = $(`&lt;div id=&quot;html_770f865297c216e073c16c0dda9b448b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_c0b0c39ce2d29e1b11c03b2ea8624e13.setContent(html_770f865297c216e073c16c0dda9b448b);
#
#
#
#         circle_4c98119315d5006866bcec59b0bad3cb.bindPopup(popup_c0b0c39ce2d29e1b11c03b2ea8624e13)
#         ;
#
#
#
#
#             var marker_03dc476edf6268fdbcc17a7a53fcd9e3 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_5013d67b16cf6e16d6dca18bf9f80d14);
#
#
#             var div_icon_c4d0e8f85c6adaba8f9ca3b31b7a2222 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_03dc476edf6268fdbcc17a7a53fcd9e3.setIcon(div_icon_c4d0e8f85c6adaba8f9ca3b31b7a2222);
#
#
#                 marker_03dc476edf6268fdbcc17a7a53fcd9e3.setIcon(div_icon_c4d0e8f85c6adaba8f9ca3b31b7a2222);
#
#
#             var circle_3f1fd87dd4f0aa8cb2c51eb4fdb0d128 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5013d67b16cf6e16d6dca18bf9f80d14);
#
#
#         var popup_386d80161801b59c1650d23920b3bb6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f9b3f6deab389a8fcd02476a1ddf184 = $(`&lt;div id=&quot;html_8f9b3f6deab389a8fcd02476a1ddf184&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_386d80161801b59c1650d23920b3bb6c.setContent(html_8f9b3f6deab389a8fcd02476a1ddf184);
#
#
#
#         circle_3f1fd87dd4f0aa8cb2c51eb4fdb0d128.bindPopup(popup_386d80161801b59c1650d23920b3bb6c)
#         ;
#
#
#
#
#             var marker_3b09496074516fce7a61f98d1325fc5a = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_5013d67b16cf6e16d6dca18bf9f80d14);
#
#
#             var div_icon_6f2ffa6a15d896d00204c41eb89f6add = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [20, 20],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_3b09496074516fce7a61f98d1325fc5a.setIcon(div_icon_6f2ffa6a15d896d00204c41eb89f6add);
#
#
#                 marker_3b09496074516fce7a61f98d1325fc5a.setIcon(div_icon_6f2ffa6a15d896

# %% [markdown]
# An example of folium.Marker:

# %%
import folium

# Crear mapa centrado en Houston, Texas
nasa_coordinates = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinates, zoom_start=10)

# Agregar un círculo
folium.Circle(
    location=nasa_coordinates,
    radius=1000,
    color='yellow',
    fill=True,
    fill_color='yellow',
    popup='NASA Johnson Space Center'
).add_to(site_map)

# Agregar un marcador
folium.Marker(
    location=nasa_coordinates,
    popup='NASA Johnson Space Center',
    icon=folium.Icon(color='green')
).add_to(site_map)

# Mostrar mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c70eb9ee205b86b70a8546603c5df20 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c70eb9ee205b86b70a8546603c5df20&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c70eb9ee205b86b70a8546603c5df20 = L.map(
#                 &quot;map_0c70eb9ee205b86b70a8546603c5df20&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96f19f06697f9557a5e770bb8a149958 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_96f19f06697f9557a5e770bb8a149958.addTo(map_0c70eb9ee205b86b70a8546603c5df20);
#
#
#             var circle_187a3412c65a18190752167ce4d67465 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0c70eb9ee205b86b70a8546603c5df20);
#
#
#         var popup_c3a0773a01a1acb7e2c32b26f5e73d5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb5b11755ce0554596767a2275df2dca = $(`&lt;div id=&quot;html_eb5b11755ce0554596767a2275df2dca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_c3a0773a01a1acb7e2c32b26f5e73d5d.setContent(html_eb5b11755ce0554596767a2275df2dca);
#
#
#
#         circle_187a3412c65a18190752167ce4d67465.bindPopup(popup_c3a0773a01a1acb7e2c32b26f5e73d5d)
#         ;
#
#
#
#
#             var marker_5e16d13d4082d64bd0ddde977f998fd3 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {
# }
#             ).addTo(map_0c70eb9ee205b86b70a8546603c5df20);
#
#
#             var icon_df388954b318677c1365bbeb1205d39c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7b30559058a3f61d7d228f99879290e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f85e2efb3ed75dc2a56db1f40a4270bc = $(`&lt;div id=&quot;html_f85e2efb3ed75dc2a56db1f40a4270bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_7b30559058a3f61d7d228f99879290e4.setContent(html_f85e2efb3ed75dc2a56db1f40a4270bc);
#
#
#
#         marker_5e16d13d4082d64bd0ddde977f998fd3.bindPopup(popup_7b30559058a3f61d7d228f99879290e4)
#         ;
#
#
#
#
#                 marker_5e16d13d4082d64bd0ddde977f998fd3.setIcon(icon_df388954b318677c1365bbeb1205d39c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label

# %% [markdown]
# El mapa generado con los sitios de lanzamiento marcados debería verse similar al siguiente:

# %% [markdown]
# Ahora puedes explorar el mapa haciendo zoom in / out en las áreas marcadas, y tratar de responder las siguientes preguntas:
#
# ¿Están todos los sitios de lanzamiento cerca de la línea del Ecuador?
#
# ¿Están todos los sitios de lanzamiento muy cerca de la costa?
#
# Además, intenta explicar tus hallazgos.

# %%
import folium

# Crear mapa centrado en EE.UU.
site_map = folium.Map(location=[28.5, -80.5], zoom_start=5)

# Recorrer cada fila del DataFrame
for index, row in spacex_df.iterrows():
    lat = row['Lat']
    lon = row['Long']
    outcome = row['class']
    site = row['Launch Site']

    # Elegir color según éxito o fallo
    color = 'green' if outcome == 1 else 'red'
    label = 'Success' if outcome == 1 else 'Failure'

    # Agregar marcador al mapa
    folium.Marker(
        location=[lat, lon],
        popup=f"{site} - {label}",
        icon=folium.Icon(color=color)
    ).add_to(site_map)

# Mostrar mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_134f676579f1f41a493a438dfb79a2d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_134f676579f1f41a493a438dfb79a2d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_134f676579f1f41a493a438dfb79a2d5 = L.map(
#                 &quot;map_134f676579f1f41a493a438dfb79a2d5&quot;,
#                 {
#                     center: [28.5, -80.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0f6f9362ac9fc983a9003d7ec73060a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0f6f9362ac9fc983a9003d7ec73060a.addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var marker_6e7d336edd3afdf74c7def6515a96238 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_4e9e0b8cf0c25ac673cae2842a36920b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_88f1f3b92d418fb4ade1b5d0fb8e123e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_470c47349ba2c5458a45f4f6c9fb4ffb = $(`&lt;div id=&quot;html_470c47349ba2c5458a45f4f6c9fb4ffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_88f1f3b92d418fb4ade1b5d0fb8e123e.setContent(html_470c47349ba2c5458a45f4f6c9fb4ffb);
#
#
#
#         marker_6e7d336edd3afdf74c7def6515a96238.bindPopup(popup_88f1f3b92d418fb4ade1b5d0fb8e123e)
#         ;
#
#
#
#
#                 marker_6e7d336edd3afdf74c7def6515a96238.setIcon(icon_4e9e0b8cf0c25ac673cae2842a36920b);
#
#
#             var marker_12a74146c179ea52575b0de6956dcb06 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_8af3a8f25f7e7ad80f556e8af101d383 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4e5b9545e55c938064eaf326bd31719e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b54489ae9fd4583e58143d846c27a7f9 = $(`&lt;div id=&quot;html_b54489ae9fd4583e58143d846c27a7f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_4e5b9545e55c938064eaf326bd31719e.setContent(html_b54489ae9fd4583e58143d846c27a7f9);
#
#
#
#         marker_12a74146c179ea52575b0de6956dcb06.bindPopup(popup_4e5b9545e55c938064eaf326bd31719e)
#         ;
#
#
#
#
#                 marker_12a74146c179ea52575b0de6956dcb06.setIcon(icon_8af3a8f25f7e7ad80f556e8af101d383);
#
#
#             var marker_053c8ee93ae25aaf5d9364f1469882f1 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_be3cad532530c229be70127bcdaa8a94 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a3693b431b522bae82540c76ee4ea644 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fdca8355d528dddd50bbc90838967d8 = $(`&lt;div id=&quot;html_2fdca8355d528dddd50bbc90838967d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_a3693b431b522bae82540c76ee4ea644.setContent(html_2fdca8355d528dddd50bbc90838967d8);
#
#
#
#         marker_053c8ee93ae25aaf5d9364f1469882f1.bindPopup(popup_a3693b431b522bae82540c76ee4ea644)
#         ;
#
#
#
#
#                 marker_053c8ee93ae25aaf5d9364f1469882f1.setIcon(icon_be3cad532530c229be70127bcdaa8a94);
#
#
#             var marker_45a5cdb0fa7bc142ff07467c669a29a6 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_f5fe2a2603704f89f55f0c6416

# %% [markdown]
# A continuación, intentemos mejorar el mapa agregando los resultados de los lanzamientos para cada sitio, y veamos cuáles tienen una alta tasa de éxito.
# Recuerda que el DataFrame spacex_df contiene registros detallados de los lanzamientos, y que la columna class indica si el lanzamiento fue exitoso o no.

# %%
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %% [markdown]
# A continuación, creemos marcadores para todos los registros de lanzamiento. Si un lanzamiento fue exitoso (class = 1), usamos un marcador verde, y si el lanzamiento falló (class = 0), usamos un marcador rojo.
#
# Ten en cuenta que un lanzamiento solo ocurre en uno de los cuatro sitios de lanzamiento, lo que significa que muchos registros de lanzamiento tendrán exactamente las mismas coordenadas. Los clústeres de marcadores (Marker Clusters) pueden ser una buena forma de simplificar un mapa que contiene muchos marcadores en la misma ubicación.
#
# Primero, creemos un objeto MarkerCluster.

# %%
marker_cluster = MarkerCluster()

# %% [markdown]
#  (TODO): Crea una nueva columna en el DataFrame spacex_df llamada marker_color para almacenar los colores de los marcadores según el valor de la columna class.

# %%
# Aplicar una función para verificar el valor de la columna `class`
# Si class = 1, el valor de marker_color será 'green'
# Si class = 0, el valor de marker_color será 'red'

spacex_df['marker_color'] = spacex_df['class'].apply(lambda x: 'green' if x == 1 else 'red')

# Verificar las primeras filas
spacex_df[['Launch Site', 'class', 'marker_color']].head()
# Out:
#    Launch Site  class marker_color
# 0  CCAFS LC-40      0          red
# 1  CCAFS LC-40      0          red
# 2  CCAFS LC-40      0          red
# 3  CCAFS LC-40      0          red
# 4  CCAFS LC-40      0          red

# %% [markdown]
# (TODO): Para cada resultado de lanzamiento en el DataFrame spacex_df, agrega un folium.Marker al marker_cluster.

# %%
# Add marker_cluster to current site_map
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed,
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for index, record in spacex_df.iterrows():
    # TODO: Create and add a Marker cluster to the site map
    # marker = folium.Marker(...)
    marker_cluster.add_child(marker)

site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_134f676579f1f41a493a438dfb79a2d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_134f676579f1f41a493a438dfb79a2d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_134f676579f1f41a493a438dfb79a2d5 = L.map(
#                 &quot;map_134f676579f1f41a493a438dfb79a2d5&quot;,
#                 {
#                     center: [28.5, -80.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0f6f9362ac9fc983a9003d7ec73060a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0f6f9362ac9fc983a9003d7ec73060a.addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var marker_6e7d336edd3afdf74c7def6515a96238 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_4e9e0b8cf0c25ac673cae2842a36920b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_88f1f3b92d418fb4ade1b5d0fb8e123e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_470c47349ba2c5458a45f4f6c9fb4ffb = $(`&lt;div id=&quot;html_470c47349ba2c5458a45f4f6c9fb4ffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_88f1f3b92d418fb4ade1b5d0fb8e123e.setContent(html_470c47349ba2c5458a45f4f6c9fb4ffb);
#
#
#
#         marker_6e7d336edd3afdf74c7def6515a96238.bindPopup(popup_88f1f3b92d418fb4ade1b5d0fb8e123e)
#         ;
#
#
#
#
#                 marker_6e7d336edd3afdf74c7def6515a96238.setIcon(icon_4e9e0b8cf0c25ac673cae2842a36920b);
#
#
#             var marker_12a74146c179ea52575b0de6956dcb06 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_8af3a8f25f7e7ad80f556e8af101d383 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4e5b9545e55c938064eaf326bd31719e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b54489ae9fd4583e58143d846c27a7f9 = $(`&lt;div id=&quot;html_b54489ae9fd4583e58143d846c27a7f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_4e5b9545e55c938064eaf326bd31719e.setContent(html_b54489ae9fd4583e58143d846c27a7f9);
#
#
#
#         marker_12a74146c179ea52575b0de6956dcb06.bindPopup(popup_4e5b9545e55c938064eaf326bd31719e)
#         ;
#
#
#
#
#                 marker_12a74146c179ea52575b0de6956dcb06.setIcon(icon_8af3a8f25f7e7ad80f556e8af101d383);
#
#
#             var marker_053c8ee93ae25aaf5d9364f1469882f1 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_be3cad532530c229be70127bcdaa8a94 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a3693b431b522bae82540c76ee4ea644 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fdca8355d528dddd50bbc90838967d8 = $(`&lt;div id=&quot;html_2fdca8355d528dddd50bbc90838967d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_a3693b431b522bae82540c76ee4ea644.setContent(html_2fdca8355d528dddd50bbc90838967d8);
#
#
#
#         marker_053c8ee93ae25aaf5d9364f1469882f1.bindPopup(p

# %%
import folium
from folium.plugins import MarkerCluster

# Crear el mapa centrado en la costa de Florida
launch_map = folium.Map(location=[28.5, -80.5], zoom_start=5)

# Crear objeto MarkerCluster
marker_cluster = MarkerCluster().add_to(launch_map)

# Recorrer cada fila del DataFrame y agregar marcadores al cluster
for index, row in spacex_df.iterrows():
    folium.Marker(
        location=[row['Lat'], row['Long']],
        popup=f"{row['Launch Site']} - {'Success' if row['class'] == 1 else 'Failure'}",
        icon=folium.Icon(color=row['marker_color'])
    ).add_to(marker_cluster)

# Mostrar el mapa
launch_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92861d876fd670d70aed71cb13d29ef2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92861d876fd670d70aed71cb13d29ef2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92861d876fd670d70aed71cb13d29ef2 = L.map(
#                 &quot;map_92861d876fd670d70aed71cb13d29ef2&quot;,
#                 {
#                     center: [28.5, -80.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3531e8e527fd737818414c6b64847128 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3531e8e527fd737818414c6b64847128.addTo(map_92861d876fd670d70aed71cb13d29ef2);
#
#
#             var marker_cluster_f9066147e0acf121ce1caf2526a13ecd = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_7848a4e00a2c75c66d24f55482e20df7 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_f9066147e0acf121ce1caf2526a13ecd);
#
#
#             var icon_08394fc30e73cc67290a2d2124d1a153 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_97d3e7d7dc3e1ff685d1ece56b522a20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fe5ffc91bcda29d80f4c539d1fb6399 = $(`&lt;div id=&quot;html_4fe5ffc91bcda29d80f4c539d1fb6399&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_97d3e7d7dc3e1ff685d1ece56b522a20.setContent(html_4fe5ffc91bcda29d80f4c539d1fb6399);
#
#
#
#         marker_7848a4e00a2c75c66d24f55482e20df7.bindPopup(popup_97d3e7d7dc3e1ff685d1ece56b522a20)
#         ;
#
#
#
#
#                 marker_7848a4e00a2c75c66d24f55482e20df7.setIcon(icon_08394fc30e73cc67290a2d2124d1a153);
#
#
#             var marker_7623ceedad827d48221bef99ba9f926a = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_f9066147e0acf121ce1caf2526a13ecd);
#
#
#             var icon_f89bccd0254952955606818e29aa0fcc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_581ba428f8ff7721a17423fff1daff93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a00b739005c6d8dcb53778d7a973852c = $(`&lt;div id=&quot;html_a00b739005c6d8dcb53778d7a973852c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_581ba428f8ff7721a17423fff1daff93.setContent(html_a00b739005c6d8dcb53778d7a973852c);
#
#
#
#         marker_7623ceedad827d48221bef99ba9f926a.bindPopup(popup_581ba428f8ff7721a17423fff1daff93)
#         ;
#
#
#
#
#                 marker_7623ceedad827d48221bef99ba9f926a.setIcon(icon_f89bccd0254952955606818e29aa0fcc);
#
#
#             var marker_9e7827f41bd6c4c96eeff6e18099658b = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(marker_cluster_f9066147e0acf121ce1caf2526a13ecd);
#
#
#             var icon_a8c2978a667cd55f24e17f0404d8c642 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a29643212c23474156d02c7e5ea4a914 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23188c8e7beb3b172bccd860d5ba462a = $(`&lt;div id=&quot;html_23188c8e7beb3b172bccd860d5ba462a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 po

# %% [markdown]
# A partir de los marcadores codificados por color dentro de los clústeres, deberías poder identificar fácilmente qué sitios de lanzamiento tienen tasas de éxito relativamente altas.

# %% [markdown]
# TAREA 3: Calcular las distancias entre un sitio de lanzamiento y sus proximidades

# %% [markdown]
# A continuación, necesitamos explorar y analizar las proximidades de los sitios de lanzamiento.
#
# Primero, agreguemos la herramienta MousePosition al mapa para obtener las coordenadas al pasar el mouse sobre un punto del mapa.
# De esta forma, mientras exploras el mapa, podrás encontrar fácilmente las coordenadas de cualquier punto de interés (como una vía de tren, por ejemplo).

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_134f676579f1f41a493a438dfb79a2d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_134f676579f1f41a493a438dfb79a2d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_134f676579f1f41a493a438dfb79a2d5 = L.map(
#                 &quot;map_134f676579f1f41a493a438dfb79a2d5&quot;,
#                 {
#                     center: [28.5, -80.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0f6f9362ac9fc983a9003d7ec73060a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0f6f9362ac9fc983a9003d7ec73060a.addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var marker_6e7d336edd3afdf74c7def6515a96238 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_4e9e0b8cf0c25ac673cae2842a36920b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_88f1f3b92d418fb4ade1b5d0fb8e123e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_470c47349ba2c5458a45f4f6c9fb4ffb = $(`&lt;div id=&quot;html_470c47349ba2c5458a45f4f6c9fb4ffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_88f1f3b92d418fb4ade1b5d0fb8e123e.setContent(html_470c47349ba2c5458a45f4f6c9fb4ffb);
#
#
#
#         marker_6e7d336edd3afdf74c7def6515a96238.bindPopup(popup_88f1f3b92d418fb4ade1b5d0fb8e123e)
#         ;
#
#
#
#
#                 marker_6e7d336edd3afdf74c7def6515a96238.setIcon(icon_4e9e0b8cf0c25ac673cae2842a36920b);
#
#
#             var marker_12a74146c179ea52575b0de6956dcb06 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_8af3a8f25f7e7ad80f556e8af101d383 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4e5b9545e55c938064eaf326bd31719e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b54489ae9fd4583e58143d846c27a7f9 = $(`&lt;div id=&quot;html_b54489ae9fd4583e58143d846c27a7f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_4e5b9545e55c938064eaf326bd31719e.setContent(html_b54489ae9fd4583e58143d846c27a7f9);
#
#
#
#         marker_12a74146c179ea52575b0de6956dcb06.bindPopup(popup_4e5b9545e55c938064eaf326bd31719e)
#         ;
#
#
#
#
#                 marker_12a74146c179ea52575b0de6956dcb06.setIcon(icon_8af3a8f25f7e7ad80f556e8af101d383);
#
#
#             var marker_053c8ee93ae25aaf5d9364f1469882f1 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_be3cad532530c229be70127bcdaa8a94 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a3693b431b522bae82540c76ee4ea644 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fdca8355d528dddd50bbc90838967d8 = $(`&lt;div id=&quot;html_2fdca8355d528dddd50bbc90

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.
#
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_134f676579f1f41a493a438dfb79a2d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_134f676579f1f41a493a438dfb79a2d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_134f676579f1f41a493a438dfb79a2d5 = L.map(
#                 &quot;map_134f676579f1f41a493a438dfb79a2d5&quot;,
#                 {
#                     center: [28.5, -80.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0f6f9362ac9fc983a9003d7ec73060a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0f6f9362ac9fc983a9003d7ec73060a.addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var marker_6e7d336edd3afdf74c7def6515a96238 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_4e9e0b8cf0c25ac673cae2842a36920b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_88f1f3b92d418fb4ade1b5d0fb8e123e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_470c47349ba2c5458a45f4f6c9fb4ffb = $(`&lt;div id=&quot;html_470c47349ba2c5458a45f4f6c9fb4ffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_88f1f3b92d418fb4ade1b5d0fb8e123e.setContent(html_470c47349ba2c5458a45f4f6c9fb4ffb);
#
#
#
#         marker_6e7d336edd3afdf74c7def6515a96238.bindPopup(popup_88f1f3b92d418fb4ade1b5d0fb8e123e)
#         ;
#
#
#
#
#                 marker_6e7d336edd3afdf74c7def6515a96238.setIcon(icon_4e9e0b8cf0c25ac673cae2842a36920b);
#
#
#             var marker_12a74146c179ea52575b0de6956dcb06 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_8af3a8f25f7e7ad80f556e8af101d383 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4e5b9545e55c938064eaf326bd31719e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b54489ae9fd4583e58143d846c27a7f9 = $(`&lt;div id=&quot;html_b54489ae9fd4583e58143d846c27a7f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40 - Failure&lt;/div&gt;`)[0];
#                 popup_4e5b9545e55c938064eaf326bd31719e.setContent(html_b54489ae9fd4583e58143d846c27a7f9);
#
#
#
#         marker_12a74146c179ea52575b0de6956dcb06.bindPopup(popup_4e5b9545e55c938064eaf326bd31719e)
#         ;
#
#
#
#
#                 marker_12a74146c179ea52575b0de6956dcb06.setIcon(icon_8af3a8f25f7e7ad80f556e8af101d383);
#
#
#             var marker_053c8ee93ae25aaf5d9364f1469882f1 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {
# }
#             ).addTo(map_134f676579f1f41a493a438dfb79a2d5);
#
#
#             var icon_be3cad532530c229be70127bcdaa8a94 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a3693b431b522bae82540c76ee4ea644 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fdca8355d528dddd50bbc90838967d8 = $(`&lt;div id=&quot;html_2fdca8355d528dddd50bbc90

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# TODO: Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch site.

# %%
# Coordenadas del sitio de lanzamiento
launch_site_lat = 28.5623
launch_site_lon = -80.5774

# Coordenadas del punto más cercano en la costa (obtenidas con MousePosition)
coastline_lat = 28.56367
coastline_lon = -80.57163

# %%
# !pip install geopy

from geopy.distance import geodesic

# Definir la función
def calculate_distance(lat1, lon1, lat2, lon2):
    point1 = (lat1, lon1)
    point2 = (lat2, lon2)
    return geodesic(point1, point2).km

# Calcular la distancia
distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)

print(f"La distancia entre el sitio de lanzamiento y la costa es de aproximadamente {distance_coastline:.2f} km.")
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.11/dist-packages (from geopy) (2.0)
# La distancia entre el sitio de lanzamiento y la costa es de aproximadamente 0.58 km.

# %%
import folium
from folium.features import DivIcon
from math import radians, cos, sin, asin, sqrt

# Función Haversine para calcular distancia en kilómetros
def haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    r = 6371  # Radio de la Tierra en km
    return c * r

# Coordenadas del sitio de lanzamiento y punto en la costa
launch_site = [28.5623, -80.5774]
coastline = [28.56367, -80.57163]

# Calcular distancia
distance = haversine(launch_site[0], launch_site[1], coastline[0], coastline[1])

# Crear el mapa centrado en el sitio de lanzamiento
site_map = folium.Map(location=launch_site, zoom_start=14)

# Agregar marcador en el sitio de lanzamiento
folium.Marker(
    launch_site,
    popup='Launch Site',
    icon=folium.Icon(color='blue')
).add_to(site_map)

# Agregar marcador en la costa
folium.Marker(
    coastline,
    popup='Coastline Point',
    icon=folium.Icon(color='green')
).add_to(site_map)

# Agregar texto de distancia en el punto costero
folium.Marker(
    location=coastline,
    icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html='<div style="font-size: 12px; color:#d35400;"><b>{:.2f} KM</b></div>'.format(distance),
    )
).add_to(site_map)

# Mostrar el mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7b06f1f0c4cad7186ea7ed2e4ce617c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7b06f1f0c4cad7186ea7ed2e4ce617c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7b06f1f0c4cad7186ea7ed2e4ce617c = L.map(
#                 &quot;map_f7b06f1f0c4cad7186ea7ed2e4ce617c&quot;,
#                 {
#                     center: [28.5623, -80.5774],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_180103fff72d04a21e966a9ebfe37da9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_180103fff72d04a21e966a9ebfe37da9.addTo(map_f7b06f1f0c4cad7186ea7ed2e4ce617c);
#
#
#             var marker_93f55e437567df9ba3a43d14854027a2 = L.marker(
#                 [28.5623, -80.5774],
#                 {
# }
#             ).addTo(map_f7b06f1f0c4cad7186ea7ed2e4ce617c);
#
#
#             var icon_c8d3e08703a3ef3ec370c3015c8c3c3b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4eb4495339609209da92d30e10015955 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a40f8dec54d45eb06d1d51c32bfea6f9 = $(`&lt;div id=&quot;html_a40f8dec54d45eb06d1d51c32bfea6f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site&lt;/div&gt;`)[0];
#                 popup_4eb4495339609209da92d30e10015955.setContent(html_a40f8dec54d45eb06d1d51c32bfea6f9);
#
#
#
#         marker_93f55e437567df9ba3a43d14854027a2.bindPopup(popup_4eb4495339609209da92d30e10015955)
#         ;
#
#
#
#
#                 marker_93f55e437567df9ba3a43d14854027a2.setIcon(icon_c8d3e08703a3ef3ec370c3015c8c3c3b);
#
#
#             var marker_c132f8876a197a4a6fc38abbc75e6a3f = L.marker(
#                 [28.56367, -80.57163],
#                 {
# }
#             ).addTo(map_f7b06f1f0c4cad7186ea7ed2e4ce617c);
#
#
#             var icon_3f806b326b350fcf860fe96311d4984b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4bd5eb8492336758b6f47426c88b9925 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdbc76311433c767938a0ae6f080d4ec = $(`&lt;div id=&quot;html_fdbc76311433c767938a0ae6f080d4ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coastline Point&lt;/div&gt;`)[0];
#                 popup_4bd5eb8492336758b6f47426c88b9925.setContent(html_fdbc76311433c767938a0ae6f080d4ec);
#
#
#
#         marker_c132f8876a197a4a6fc38abbc75e6a3f.bindPopup(popup_4bd5eb8492336758b6f47426c88b9925)
#         ;
#
#
#
#
#                 marker_c132f8876a197a4a6fc38abbc75e6a3f.setIcon(icon_3f806b326b350fcf860fe96311d4984b);
#
#
#             var marker_545574a5e20111fa32d5e9f34fff017b = L.marker(
#                 [28.56367, -80.57163],
#                 {
# }
#             ).addTo(map_f7b06f1f0c4cad7186ea7ed2e4ce617c);
#
#
#             var div_icon_fbe32a4a8bcf1692e79707002be5c601 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:#d35400;\&quot;\u003e\u003cb\u003e0.58 KM\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [150, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_545574a5e20111fa32d5e9f34fff017b.setIcon(div_icon_fbe32a4a8bcf1692e79707002be5c601);
#
#
#                 marker_545574a5e20111fa32d5e9f34fff017b.setIcon(div_icon_fbe32a4a8bcf1692e79707002be5c601);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# TODO): Dibujar una línea (PolyLine) entre un sitio de lanzamiento y el punto de la costa seleccionado.

# %%
import folium
from folium.features import DivIcon
from math import radians, cos, sin, asin, sqrt

# Función para calcular distancia con fórmula Haversine
def haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    r = 6371
    return c * r

# Coordenadas
launch_site = [28.5623, -80.5774]
coastline = [28.56367, -80.57163]

# Calcular distancia
distance = haversine(launch_site[0], launch_site[1], coastline[0], coastline[1])

# Crear el mapa
site_map = folium.Map(location=launch_site, zoom_start=14)

# Marcadores
folium.Marker(launch_site, popup='Launch Site', icon=folium.Icon(color='blue')).add_to(site_map)
folium.Marker(coastline, popup='Coastline', icon=folium.Icon(color='green')).add_to(site_map)

# Texto con la distancia
folium.Marker(
    location=coastline,
    icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html='<div style="font-size: 12px; color:#d35400;"><b>{:.2f} KM</b></div>'.format(distance),
    )
).add_to(site_map)

# 👉 Dibujar la línea entre los dos puntos
coordinates = [launch_site, coastline]
line = folium.PolyLine(locations=coordinates, weight=2, color='blue')
site_map.add_child(line)

# Mostrar mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9cd88ac5c6b9b2c9ebd4fe9a700ef5c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9cd88ac5c6b9b2c9ebd4fe9a700ef5c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9cd88ac5c6b9b2c9ebd4fe9a700ef5c4 = L.map(
#                 &quot;map_9cd88ac5c6b9b2c9ebd4fe9a700ef5c4&quot;,
#                 {
#                     center: [28.5623, -80.5774],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d84be4815d67920fee6249ef8d67b19a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d84be4815d67920fee6249ef8d67b19a.addTo(map_9cd88ac5c6b9b2c9ebd4fe9a700ef5c4);
#
#
#             var marker_e29a42c02b62369e15eaf575e5179419 = L.marker(
#                 [28.5623, -80.5774],
#                 {
# }
#             ).addTo(map_9cd88ac5c6b9b2c9ebd4fe9a700ef5c4);
#
#
#             var icon_1072690d57a23adc1b173e64e0a17b61 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c8e8a32fc2c8919cd05e0318475a17e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbdcb75b351c798e9ca4d5aac8fb8f43 = $(`&lt;div id=&quot;html_fbdcb75b351c798e9ca4d5aac8fb8f43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site&lt;/div&gt;`)[0];
#                 popup_c8e8a32fc2c8919cd05e0318475a17e8.setContent(html_fbdcb75b351c798e9ca4d5aac8fb8f43);
#
#
#
#         marker_e29a42c02b62369e15eaf575e5179419.bindPopup(popup_c8e8a32fc2c8919cd05e0318475a17e8)
#         ;
#
#
#
#
#                 marker_e29a42c02b62369e15eaf575e5179419.setIcon(icon_1072690d57a23adc1b173e64e0a17b61);
#
#
#             var marker_69510016e7d8ce37d160ffa3d48dde04 = L.marker(
#                 [28.56367, -80.57163],
#                 {
# }
#             ).addTo(map_9cd88ac5c6b9b2c9ebd4fe9a700ef5c4);
#
#
#             var icon_0d4a8f73a50e5b14219b31f3526dbd6e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c66aa7c94d2389c390c8198df05a8fd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca5b3485f235c1dc9ba9013e6397cf1e = $(`&lt;div id=&quot;html_ca5b3485f235c1dc9ba9013e6397cf1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coastline&lt;/div&gt;`)[0];
#                 popup_c66aa7c94d2389c390c8198df05a8fd4.setContent(html_ca5b3485f235c1dc9ba9013e6397cf1e);
#
#
#
#         marker_69510016e7d8ce37d160ffa3d48dde04.bindPopup(popup_c66aa7c94d2389c390c8198df05a8fd4)
#         ;
#
#
#
#
#                 marker_69510016e7d8ce37d160ffa3d48dde04.setIcon(icon_0d4a8f73a50e5b14219b31f3526dbd6e);
#
#
#             var marker_d93ea2d8e2cfbf758f14cf70965907ad = L.marker(
#                 [28.56367, -80.57163],
#                 {
# }
#             ).addTo(map_9cd88ac5c6b9b2c9ebd4fe9a700ef5c4);
#
#
#             var div_icon_c0f22c23080c4e46eee96fda08062b46 = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:#d35400;\&quot;\u003e\u003cb\u003e0.58 KM\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [150, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_d93ea2d8e2cfbf758f14cf70965907ad.setIcon(div_icon_c0f22c23080c4e46eee96fda08062b46);
#
#
#                 marker_d93ea2d8e2cfbf758f14cf70965907ad.setIcon(div_icon_c0f22c23080c4e46eee96fda08062b46);
#
#
#             var poly_line_6fad4c1e4dc9fe86c7981dcd2c9523f2 = L.polyline(
#                 [[28.5623, -80.5774], [28.56367, -80.57163]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_9cd88ac5c6b9b2c9ebd4fe9a700ef5c4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100

# %% [markdown]
# TODO): De manera similar, puedes dibujar una línea entre un sitio de lanzamiento y la ciudad, vía férrea, autopista, etc. más cercana. Primero necesitas usar MousePosition para encontrar sus coordenadas en el mapa.

# %%
import folium
from folium.features import DivIcon
from math import radians, cos, sin, asin, sqrt

# Función para calcular la distancia
def haversine(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    r = 6371
    return c * r

# Coordenadas del sitio de lanzamiento
launch_site = [28.5623, -80.5774]

# Coordenadas del punto cercano (ciudad, tren, autopista, etc.)
# Reemplaza por las que tú encuentres con MousePosition
closest_point = [28.6100, -80.8000]  # <- ejemplo de una ciudad

# Calcular distancia
distance = haversine(launch_site[0], launch_site[1], closest_point[0], closest_point[1])

# Crear el mapa
site_map = folium.Map(location=launch_site, zoom_start=10)

# Marcador sitio de lanzamiento
folium.Marker(
    launch_site,
    popup='Launch Site',
    icon=folium.Icon(color='blue')
).add_to(site_map)

# Marcador del punto cercano (ciudad, vía, autopista)
folium.Marker(
    closest_point,
    popup='Punto cercano',
    icon=folium.Icon(color='purple')
).add_to(site_map)

# Mostrar distancia en texto
folium.Marker(
    location=closest_point,
    icon=DivIcon(
        icon_size=(150,36),
        icon_anchor=(0,0),
        html='<div style="font-size: 12px; color:#800080;"><b>{:.2f} KM</b></div>'.format(distance),
    )
).add_to(site_map)

# Dibujar línea entre el sitio de lanzamiento y el punto cercano
folium.PolyLine(
    locations=[launch_site, closest_point],
    weight=2,
    color='purple'
).add_to(site_map)

# Mostrar mapa
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92cd547b929d69077884bf99f49f25aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92cd547b929d69077884bf99f49f25aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92cd547b929d69077884bf99f49f25aa = L.map(
#                 &quot;map_92cd547b929d69077884bf99f49f25aa&quot;,
#                 {
#                     center: [28.5623, -80.5774],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3bbb58dce564dd65abae40a68986a0a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b3bbb58dce564dd65abae40a68986a0a.addTo(map_92cd547b929d69077884bf99f49f25aa);
#
#
#             var marker_371c2adb47cc01d29aaf7408e6a0aaf0 = L.marker(
#                 [28.5623, -80.5774],
#                 {
# }
#             ).addTo(map_92cd547b929d69077884bf99f49f25aa);
#
#
#             var icon_1fb6d2e14149e1a34e2da62872d14657 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f6a22f1399a6b87b79059bfa9bcf8240 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9497f4fd2842736e736dce66d375689c = $(`&lt;div id=&quot;html_9497f4fd2842736e736dce66d375689c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Site&lt;/div&gt;`)[0];
#                 popup_f6a22f1399a6b87b79059bfa9bcf8240.setContent(html_9497f4fd2842736e736dce66d375689c);
#
#
#
#         marker_371c2adb47cc01d29aaf7408e6a0aaf0.bindPopup(popup_f6a22f1399a6b87b79059bfa9bcf8240)
#         ;
#
#
#
#
#                 marker_371c2adb47cc01d29aaf7408e6a0aaf0.setIcon(icon_1fb6d2e14149e1a34e2da62872d14657);
#
#
#             var marker_0445fbb9984a02fea13a65fd74453f19 = L.marker(
#                 [28.61, -80.8],
#                 {
# }
#             ).addTo(map_92cd547b929d69077884bf99f49f25aa);
#
#
#             var icon_013f5f6afcec32bc547a9a17755e8792 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3c04cfca8832e5983648cc989e8a8bf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f96923285bac738a0e2103bead9595cc = $(`&lt;div id=&quot;html_f96923285bac738a0e2103bead9595cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Punto cercano&lt;/div&gt;`)[0];
#                 popup_3c04cfca8832e5983648cc989e8a8bf6.setContent(html_f96923285bac738a0e2103bead9595cc);
#
#
#
#         marker_0445fbb9984a02fea13a65fd74453f19.bindPopup(popup_3c04cfca8832e5983648cc989e8a8bf6)
#         ;
#
#
#
#
#                 marker_0445fbb9984a02fea13a65fd74453f19.setIcon(icon_013f5f6afcec32bc547a9a17755e8792);
#
#
#             var marker_4822b3b44d2b795685b701583a5852c9 = L.marker(
#                 [28.61, -80.8],
#                 {
# }
#             ).addTo(map_92cd547b929d69077884bf99f49f25aa);
#
#
#             var div_icon_c59808568cba55a2e318ab85b7f186da = L.divIcon({
#   &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12px; color:#800080;\&quot;\u003e\u003cb\u003e22.37 KM\u003c/b\u003e\u003c/div\u003e&quot;,
#   &quot;iconSize&quot;: [150, 36],
#   &quot;iconAnchor&quot;: [0, 0],
#   &quot;className&quot;: &quot;empty&quot;,
# });
#             marker_4822b3b44d2b795685b701583a5852c9.setIcon(div_icon_c59808568cba55a2e318ab85b7f186da);
#
#
#                 marker_4822b3b44d2b795685b701583a5852c9.setIcon(div_icon_c59808568cba55a2e318ab85b7f186da);
#
#
#             var poly_line_f814482a3a56fa085f0e96a4860b1ca3 = L.polyline(
#                 [[28.5623, -80.5774], [28.61, -80.8]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;purple&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_92cd547b929d69077884bf99f49f25aa);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;to

# %% [markdown]
# ✍️ Análisis de proximidades de los sitios de lanzamiento
# Luego de trazar líneas desde el sitio de lanzamiento hacia diferentes puntos de interés (costa, autopistas, vías férreas y ciudad), se pueden realizar las siguientes observaciones:
#
# ¿Están los sitios de lanzamiento cerca de vías férreas?
# Sí. El sitio de lanzamiento analizado se encuentra en proximidad directa a una vía férrea, lo que facilita el transporte de equipos pesados y componentes necesarios para el lanzamiento.
#
# ¿Están los sitios de lanzamiento cerca de autopistas?
# Sí. Se observan autopistas principales a corta distancia del sitio, lo cual permite un acceso terrestre eficiente tanto para personal como para logística.
#
# ¿Están los sitios de lanzamiento cerca de la costa?
# Sí. El sitio está ubicado a pocos kilómetros de la costa, lo que es ideal por razones de seguridad (permitiendo que las etapas caigan en el océano) y también por la facilidad de transporte marítimo.
#
# ¿Se mantienen los sitios de lanzamiento a cierta distancia de las ciudades?
# Efectivamente. Aunque hay ciudades relativamente cercanas (como Titusville), los sitios de lanzamiento se mantienen alejados de zonas urbanas densas, probablemente por razones de seguridad y control de riesgos en caso de fallos.
#
# ✅ Conclusión
# Los sitios de lanzamiento analizados muestran una ubicación estratégica: cercanos a infraestructuras clave como autopistas y ferrocarriles, pero al mismo tiempo lo suficientemente alejados de áreas urbanas densas y cerca del mar, lo cual es ideal para operaciones aeroespaciales seguras y eficientes.

# %% [markdown]
# Después de trazar las líneas de distancia hacia los puntos cercanos, puedes responder fácilmente las siguientes preguntas:
# ¿Los sitios de lanzamiento están cerca de vías férreas?
#
# ¿Los sitios de lanzamiento están cerca de autopistas?
#
# ¿Los sitios de lanzamiento están cerca de la costa?
#
# ¿Los sitios de lanzamiento mantienen cierta distancia respecto a las ciudades?
#
# Además, intenta explicar tus hallazgos.
